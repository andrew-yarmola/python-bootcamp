# %%
from dsio.main import restream_dataframe
from dsio.anomaly_detectors import Percentile1D
import pandas as pd
dataframe = pd.read_csv('data/cardata_sample.csv', sep=',')
detector = Percentile1D
restream_dataframe(dataframe, detector, sensors=['engine_speed',
                                                   'vehicle_speed', 
                                                   'accelerator_pedal_position', 
                                                   'torque_at_transmission'], cols=2, speed=50)
# Out:
# data found from 2013-05-24 14:21:37 to 2013-05-24 14:44:13
# Converting to milliseconds ...
# Done
# Adding time offset of 196438119.09 seconds
# Setting speed to 50x
# Done
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:53324/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:53324&resources=none" id="1002"></script>
# Writing 150 rows dated 2019-08-15 04:30:16.494000 to 2019-08-15 04:30:19.494000
# ......
# Writing 150 rows dated 2019-08-15 04:30:19.494000 to 2019-08-15 04:30:22.494000
# ...
# Writing 150 rows dated 2019-08-15 04:30:22.494000 to 2019-08-15 04:30:25.494000
# ...
# Writing 150 rows dated 2019-08-15 04:30:25.494000 to 2019-08-15 04:30:28.494000
# ...
# Writing 78 rows dated 2019-08-15 04:30:28.494000 to 2019-08-15 04:30:31.494000
# .
# Writing 150 rows dated 2019-08-15 04:30:30.074000 to 2019-08-15 04:30:33.074000
# ...
# Writing 150 rows dated 2019-08-15 04:30:33.074000 to 2019-08-15 04:30:36.074000
# .
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 828, in callback
#     result_list.append(f.result())
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 191, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1127, in wrapper
#     return doc._with_self_as_curdoc(invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1126, in invoke
#     return f(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/src/dsio/dsio/dashboard/bokeh.py", line 65, in update
#     source.stream(data)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 413, in stream
#     self._stream(new_data, rollover)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 525, in _stream
#     self.data._stream(self.document, self, new_data, rollover, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 444, in _stream
#     hint=ColumnsStreamedEvent(doc, source, new_data, rollover, setter))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 152, in _notify_owners
#     descriptor._notify_mutated(owner, old, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 875, in _notify_mutated
#     self._real_set(obj, old, value, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/model.py", line 704, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1100, in _trigger_on_change
#     self._with_self_as_curdoc(invoke_callbacks)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1099, in invoke_callbacks
#     cb(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 669, in <lambda>
#     self._callbacks[receiver] = lambda event: event.dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 244, in dispatch
#     super(ModelChangedEvent, self).dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 126, in dispatch
#     receiver._document_patched(self)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 223, in _document_patched
#     self._pending_writes.append(connection.send_patch_document(event))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/connection.py", line 76, in send_patch_document
#     msg = self.protocol.create('PATCH-DOC', [event])
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/__init__.py", line 80, in create
#     return self._messages[msgtype].create(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 93, in create
#     patch_json, buffers = process_document_events(events, use_buffers)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 136, in process_document_events
#     return serialize_json(json), buffers if use_buffers else []
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/json_encoder.py", line 161, in serialize_json
#     return json.dumps(obj, cls=BokehJSONEncoder, allow_nan=False, indent=indent, separators=separators, sort_keys=True, **kwargs)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py", line 238, in dumps
#     **kw).encode(obj)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
# ..
# Writing 150 rows dated 2019-08-15 04:30:36.074000 to 2019-08-15 04:30:39.074000
# .
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 828, in callback
#     result_list.append(f.result())
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 191, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1127, in wrapper
#     return doc._with_self_as_curdoc(invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1126, in invoke
#     return f(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/src/dsio/dsio/dashboard/bokeh.py", line 65, in update
#     source.stream(data)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 413, in stream
#     self._stream(new_data, rollover)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 525, in _stream
#     self.data._stream(self.document, self, new_data, rollover, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 444, in _stream
#     hint=ColumnsStreamedEvent(doc, source, new_data, rollover, setter))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 152, in _notify_owners
#     descriptor._notify_mutated(owner, old, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 875, in _notify_mutated
#     self._real_set(obj, old, value, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/model.py", line 704, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1100, in _trigger_on_change
#     self._with_self_as_curdoc(invoke_callbacks)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1099, in invoke_callbacks
#     cb(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 669, in <lambda>
#     self._callbacks[receiver] = lambda event: event.dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 244, in dispatch
#     super(ModelChangedEvent, self).dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 126, in dispatch
#     receiver._document_patched(self)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 223, in _document_patched
#     self._pending_writes.append(connection.send_patch_document(event))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/connection.py", line 76, in send_patch_document
#     msg = self.protocol.create('PATCH-DOC', [event])
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/__init__.py", line 80, in create
#     return self._messages[msgtype].create(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 93, in create
#     patch_json, buffers = process_document_events(events, use_buffers)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 136, in process_document_events
#     return serialize_json(json), buffers if use_buffers else []
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/json_encoder.py", line 161, in serialize_json
#     return json.dumps(obj, cls=BokehJSONEncoder, allow_nan=False, indent=indent, separators=separators, sort_keys=True, **kwargs)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py", line 238, in dumps
#     **kw).encode(obj)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
# ..
# Writing 150 rows dated 2019-08-15 04:30:39.074000 to 2019-08-15 04:30:42.074000
# .
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 828, in callback
#     result_list.append(f.result())
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 191, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1127, in wrapper
#     return doc._with_self_as_curdoc(invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1126, in invoke
#     return f(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/src/dsio/dsio/dashboard/bokeh.py", line 65, in update
#     source.stream(data)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 413, in stream
#     self._stream(new_data, rollover)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 525, in _stream
#     self.data._stream(self.document, self, new_data, rollover, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 444, in _stream
#     hint=ColumnsStreamedEvent(doc, source, new_data, rollover, setter))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 152, in _notify_owners
#     descriptor._notify_mutated(owner, old, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 875, in _notify_mutated
#     self._real_set(obj, old, value, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/model.py", line 704, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1100, in _trigger_on_change
#     self._with_self_as_curdoc(invoke_callbacks)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1099, in invoke_callbacks
#     cb(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 669, in <lambda>
#     self._callbacks[receiver] = lambda event: event.dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 244, in dispatch
#     super(ModelChangedEvent, self).dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 126, in dispatch
#     receiver._document_patched(self)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 223, in _document_patched
#     self._pending_writes.append(connection.send_patch_document(event))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/connection.py", line 76, in send_patch_document
#     msg = self.protocol.create('PATCH-DOC', [event])
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/__init__.py", line 80, in create
#     return self._messages[msgtype].create(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 93, in create
#     patch_json, buffers = process_document_events(events, use_buffers)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 136, in process_document_events
#     return serialize_json(json), buffers if use_buffers else []
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/json_encoder.py", line 161, in serialize_json
#     return json.dumps(obj, cls=BokehJSONEncoder, allow_nan=False, indent=indent, separators=separators, sort_keys=True, **kwargs)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py", line 238, in dumps
#     **kw).encode(obj)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
# ..
# ERROR:bokeh.util.tornado:Error thrown from periodic callback:
# ERROR:bokeh.util.tornado:Traceback (most recent call last):
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 828, in callback
#     result_list.append(f.result())
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 191, in with_document_locked
#     return func(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1127, in wrapper
#     return doc._with_self_as_curdoc(invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1126, in invoke
#     return f(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/src/dsio/dsio/dashboard/bokeh.py", line 65, in update
#     source.stream(data)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 413, in stream
#     self._stream(new_data, rollover)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/models/sources.py", line 525, in _stream
#     self.data._stream(self.document, self, new_data, rollover, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 444, in _stream
#     hint=ColumnsStreamedEvent(doc, source, new_data, rollover, setter))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/wrappers.py", line 152, in _notify_owners
#     descriptor._notify_mutated(owner, old, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 875, in _notify_mutated
#     self._real_set(obj, old, value, hint=hint)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/model.py", line 704, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1100, in _trigger_on_change
#     self._with_self_as_curdoc(invoke_callbacks)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 1099, in invoke_callbacks
#     cb(event)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/document.py", line 669, in <lambda>
#     self._callbacks[receiver] = lambda event: event.dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 244, in dispatch
#     super(ModelChangedEvent, self).dispatch(receiver)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/document/events.py", line 126, in dispatch
#     receiver._document_patched(self)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/session.py", line 223, in _document_patched
#     self._pending_writes.append(connection.send_patch_document(event))
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/server/connection.py", line 76, in send_patch_document
#     msg = self.protocol.create('PATCH-DOC', [event])
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/__init__.py", line 80, in create
#     return self._messages[msgtype].create(*args, **kwargs)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 93, in create
#     patch_json, buffers = process_document_events(events, use_buffers)
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/protocol/messages/patch_doc.py", line 136, in process_document_events
#     return serialize_json(json), buffers if use_buffers else []
#   File "/Users/yarmola/.local/share/virtualenvs/data_mining-xIzjQ1YQ/lib/python3.7/site-packages/bokeh/core/json_encoder.py", line 161, in serialize_json
#     return json.dumps(obj, cls=BokehJSONEncoder, allow_nan=False, indent=indent, separators=separators, sort_keys=True, **kwargs)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py", line 238, in dumps
#     **kw).encode(obj)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
# Writing 77 rows dated 2019-08-15 04:30:42.074000 to 2019-08-15 04:30:45.074000
